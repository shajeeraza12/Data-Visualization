# %% [markdown]
# <a href="https://colab.research.google.com/github/shajeeraza12/Data-Visualization/blob/main/DWTask2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

file_path = '/content/DatasetAfricaMalaria.csv'
data = pd.read_csv(file_path)
data.head()
# Out:
#    Country Name  Year Country Code  \
# 0       Algeria  2007          DZA
# 1        Angola  2007          AGO
# 2         Benin  2007          BEN
# 3      Botswana  2007          BWA
# 4  Burkina Faso  2007          BFA
#
#    Incidence of malaria (per 1,000 population at risk)  \
# 0                                               0.01
# 1                                             286.72
# 2                                             480.24
# 3                                               1.03
# 4                                             503.80
#
#    Malaria cases reported  \
# 0                    26.0
# 1               1533485.0
# 2                     0.0
# 3                   390.0
# 4                 44246.0
#
#    Use of insecticide-treated bed nets (% of under-5 population)  \
# 0                                                NaN
# 1                                               18.0
# 2                                                NaN
# ...

# %%
# Extracting the necessary columns: Country Name, Year, and Malaria Cases Reported
columns_needed = ['Country Name', 'Year', 'Malaria cases reported']
extracted_data = data[columns_needed]
extracted_data.head()
# Out:
#    Country Name  Year  Malaria cases reported
# 0       Algeria  2007                    26.0
# 1        Angola  2007               1533485.0
# 2         Benin  2007                     0.0
# 3      Botswana  2007                   390.0
# 4  Burkina Faso  2007                 44246.0

# %%
# Summing malaria cases reported for each country from 2007 to 2017
aggregated_data = extracted_data.groupby('Country Name')['Malaria cases reported'].sum().reset_index()
aggregated_data.columns = ['Country Name', 'Total Malaria Cases']
aggregated_data.head()
# Out:
#    Country Name  Total Malaria Cases
# 0       Algeria                 94.0
# 1        Angola           24034182.0
# 2         Benin            8579720.0
# 3      Botswana               8756.0
# 4  Burkina Faso           41601963.0

# %%
# Importing necessary libraries
import plotly.express as px

# Creating the heatmap
fig = px.choropleth(
    africa_data,
    locations="Country Name",
    locationmode="country names",
    color="Total Malaria Cases",
    title="Number of Malaria Cases Reported from 2007 to 2017 in Africa",
    color_continuous_scale="Reds"
)

# Updating geographical settings to focus only on Africa
fig.update_geos(
    scope="africa",
    showland=True,
    landcolor="lightgrey",
    showocean=True,
    oceancolor="lightblue",
    coastlinecolor="black"
)

# Adjusting the size of the plot
fig.update_layout(
    width=900,
    height=700,
    title_font=dict(size=20)
)

# Adding hover data to show detailed information
fig.update_traces(
    hovertemplate='<b>Country:</b> %{location}<br>' +
                  '<b>Cases Reported:</b> %{z}<extra></extra>'
)

# Displaying the heatmap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
